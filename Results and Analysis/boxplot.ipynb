# %%
import pandas as pd
import matplotlib.pyplot as plt
# File names with long paths
file_names = [
    './resultscmaes/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10_cleaned_final.csv',
    './resultscmaes_around/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCC=CCC=CCC=CCCCCCCC(C)C(=O)S(=O)(=O)O_0.9_50_10_cleaned_final.csv',
    './resultsnsga/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10_cleaned_final.csv',  
    './resultsnsga_around/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCC=CCC=CCC=CCCCCCCC(C)C(=O)S(=O)(=O)O_0.9_50_10_cleaned_final.csv'
]

# Custom column names
column_names = ['First Degree MO-CMA-ES', 'Second Degree MO-CMA-ES', 'First Degree NSGA', 'Second Degree NSGA']

# Reading the specific column 'XLogP' from each CSV file
normalized_data = []
min = 5
max = 10
for file_name in file_names:
    df = pd.read_csv(file_name)
    normalized_df = (df['XLogP'] - min) / (max - min)
    normalized_data.append(normalized_df)

temp = (7.2- min) / (max - min)
# Fixed value to be added as a dot in each box plot
fixed_values = [temp, temp, temp, temp] 

# Creating the box plot
plt.figure(figsize=(10, 6))

# Plotting box plots for each dataset
boxplots = plt.boxplot(normalized_data, notch=False, patch_artist=True, labels=column_names)

# Set the color of each box plot to light green
for box in boxplots['boxes']:
    box.set_facecolor('lightgreen')

# Adding fixed value as a dot in each boxplot
dots = [plt.plot(i + 1, fixed_value, 'ro')[0] for i, fixed_value in enumerate(fixed_values)]

# Adding legend for the fixed value dot
plt.legend(dots,['Starting Molecule'], loc='lower right')

plt.title('XLogP Value of Final Frontier Molecules from Different Algorithms')
plt.ylabel('XLogP Value')

# Set y-axis limits
plt.ylim([0, 0.5])  # Replace min_value and max_value with desired y-axis limits

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# File names with long paths
file_names = [
    './resultscmaes/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10_cleaned_final.csv',
    './resultscmaes_around/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCC=CCC=CCC=CCCCCCCC(C)C(=O)S(=O)(=O)O_0.9_50_10_cleaned_final.csv',
    './resultsnsga/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10_cleaned_final.csv',  
    './resultsnsga_around/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCC=CCC=CCC=CCCCCCCC(C)C(=O)S(=O)(=O)O_0.9_50_10_cleaned_final.csv'
]

# Custom column names
column_names = ['First Degree MO-CMA-ES', 'Second Degree MO-CMA-ES', 'First Degree NSGA', 'Second Degree NSGA']

# Reading the specific column 'XLogP' from each CSV file
normalized_data = []
min = 250
max = 350
for file_name in file_names:
    df = pd.read_csv(file_name)
    normalized_df = (df['Complexity'] - min) / (max - min)
    normalized_data.append(normalized_df)

temp = (322- min) / (max - min)
# Fixed value to be added as a dot in each box plot
fixed_values = [temp, temp, temp, temp] 

# Creating the box plot
plt.figure(figsize=(10, 6))

# Plotting box plots for each dataset
boxplots = plt.boxplot(normalized_data, notch=False, patch_artist=True, labels=column_names)

# Set the color of each box plot to light green
for box in boxplots['boxes']:
    box.set_facecolor('lightgreen')

# Adding fixed value as a dot in each boxplot
dots = [plt.plot(i + 1, fixed_value, 'ro')[0] for i, fixed_value in enumerate(fixed_values)]

# Adding legend for the fixed value dot
plt.legend(dots,['Starting Molecule'], loc='lower right')

plt.title('Molecular Complexity of Final Frontier Molecules from Different Algorithms')
plt.ylabel('Molecular Complexity')

# Set y-axis limits
plt.ylim([0, 1])  # Replace min_value and max_value with desired y-axis limits

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# File names with long paths
file_names = [
    './resultscmaes/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10_cleaned_final.csv',
    './resultscmaes_around/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCC=CCC=CCC=CCCCCCCC(C)C(=O)S(=O)(=O)O_0.9_50_10_cleaned_final.csv',
    './resultsnsga/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10_cleaned_final.csv',  
    './resultsnsga_around/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCC=CCC=CCC=CCCCCCCC(C)C(=O)S(=O)(=O)O_0.9_50_10_cleaned_final.csv'
]
# Custom column names
column_names = ['First Degree MO-CMA-ES', 'Second Degree MO-CMA-ES', 'First Degree NSGA', 'Second Degree NSGA']

# Reading the specific column 'XLogP' from each CSV file
normalized_data = []
min = 250
max = 350
for file_name in file_names:
    df = pd.read_csv(file_name)
    normalized_df = (df['MolecularWeight'] - min) / (max - min)
    normalized_data.append(normalized_df)

temp = (336.5- min) / (max - min)
# Fixed value to be added as a dot in each box plot
fixed_values = [temp, temp, temp, temp]  # Example fixed values

# Creating the box plot
plt.figure(figsize=(10, 6))

# Plotting box plots for each dataset
boxplots = plt.boxplot(normalized_data, notch=False, patch_artist=True, labels=column_names)

# Set the color of each box plot to light green
for box in boxplots['boxes']:
    box.set_facecolor('lightgreen')

# Adding fixed value as a dot in each boxplot
dots = [plt.plot(i + 1, fixed_value, 'ro')[0] for i, fixed_value in enumerate(fixed_values)]

# Adding legend for the fixed value dot
plt.legend(dots,['Starting Molecule'], loc='lower right')

plt.title('Molecular Weight of Final Frontier Molecules from Different Algorithms')
plt.ylabel('Molecular Weight')


# Set y-axis limits
plt.ylim([0.5, 1])  # Replace min_value and max_value with desired y-axis limits

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import MACCSkeys
from rdkit import DataStructs

mol2 = Chem.MolFromSmiles('CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O')
fp2 = MACCSkeys.GenMACCSKeys(mol2)

def calculate_similarity_reference(smiles2, fp2 = fp2, threshold = 0.9):
    """
    Calculate the similarity between two molecules using MACCS keys.
    
    :param smiles1: SMILES notation of the first molecule.
    :param smiles2: SMILES notation of the second molecule.
    :return: Tanimoto similarity coefficient.
    """
    # Convert the SMILES strings to RDKit molecule objects

    mol = Chem.MolFromSmiles(smiles2)

    if mol is None or mol2 is None:
        raise ValueError("Invalid SMILES string provided.")

    # Generate the MACCS fingerprints
    fp1 = MACCSkeys.GenMACCSKeys(mol)
    #fp2 = MACCSkeys.GenMACCSKeys(mol2)

    # Calculate Tanimoto similarity
    similarity = DataStructs.TanimotoSimilarity(fp1, fp2)
    #similarity = abs(similarity-threshold)
    return round(similarity, 2)

# File names with long paths
file_names = [
    './resultscmaes/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10_cleaned_final.csv',
    './resultscmaes_around/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCC=CCC=CCC=CCCCCCCC(C)C(=O)S(=O)(=O)O_0.9_50_10_cleaned_final.csv',
    './resultsnsga/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10_cleaned_final.csv',  
    './resultsnsga_around/CCCCCCC(C)CCCCCCCCCOS(=O)(=O)O_0.9_50_10/CCC=CCC=CCC=CCCCCCCC(C)C(=O)S(=O)(=O)O_0.9_50_10_cleaned_final.csv'
]

# Custom column names
column_names = ['First Degree MO-CMA-ES', 'Second Degree MO-CMA-ES', 'First Degree NSGA', 'Second Degree NSGA']

# Reading the specific column 'XLogP' from each CSV file
data = [pd.read_csv(file)['SMILES'].apply(lambda x: calculate_similarity_reference(x)) for file in file_names]

# Fixed value to be added as a dot in each box plot
fixed_values = [1, 1, 1, 1]  # Example fixed values

# Creating the box plot
plt.figure(figsize=(10, 6))

# Plotting box plots for each dataset
boxplots = plt.boxplot(data, notch=False, patch_artist=True, labels=column_names)

# Set the color of each box plot to light green
for box in boxplots['boxes']:
    box.set_facecolor('lightgreen')

# Adding fixed value as a dot in each boxplot
dots = [plt.plot(i + 1, fixed_value, 'ro')[0] for i, fixed_value in enumerate(fixed_values)]

# Adding legend for the fixed value dot
plt.legend(dots,['Starting Molecule'], loc='lower right')

plt.title('Reference Likeness of Final Frontier Molecules from Different Algorithms')
plt.ylabel('Reference Likeness')

# Set y-axis limits
plt.ylim([0.6, 1])  # Replace min_value and max_value with desired y-axis limits

# Show the plot
plt.show()

# %%
        f = f[f['Complexity'] <= 300]
        f = f[f['MolecularWeight'] <= 300]
        f = f[f['RefLikeness'] >= 0.7]
        f = f[f['XLogP'] <= 9]

        f = f[f['Complexity'] >= 200]
        f = f[f['MolecularWeight'] >= 200]
        f = f[f['XLogP'] >= 3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 f = f[f['Complexity'] <= 300]
#       2 f = f[f['MolecularWeight'] <= 300]
#       3 f = f[f['RefLikeness'] >= 0.7]
#
# NameError: name 'f' is not defined
